# %% [markdown]
# # Subtly corrupted inline image
#
# Base64 is valid and PNG chunks/CRC look valid, but IDAT is not a zlib stream.
#
# corrupt png

# %%
# output intentionally contains subtly corrupted PNG bytes

# %% [markdown]
# # Subtly corrupted attachment image
#
# ![corrupt attachment](attachment:corrupt.png)
